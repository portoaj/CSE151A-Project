# %% [markdown]
# # Training the final(third) model using the labeled data

# %%
# !pip install ultralytics pillow

# Fix for issue preventing the rm rf from https://stackoverflow.com/questions/56081324/why-are-google-colab-shell-commands-not-working
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# Get annotated data for model training
# !rm -rf AnnotatedDataYoloFormat
# !rm -rf AnnotatedDataYoloFormat.zip
# !wget -q https://github.com/portoaj/CSE151A-Project/raw/main/AnnotatedDataYoloFormat.zip
# !unzip -n -qq AnnotatedDataYoloFormat.zip -d AnnotatedDataYoloFormat

# %%
# !rm -rf runs
from ultralytics import YOLO

# Code sourced/ modified from the github page: https://github.com/ultralytics/ultralytics
# And from the docs: https://docs.ultralytics.com/modes/train/#train-settings


model = YOLO("yolov8s.pt")
model.train(data="/content/AnnotatedDataYoloFormat/data.yaml", epochs=100, batch=8, plots=True, seed=0, patience=25)
# Out:
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from PIL import Image

# Printing the training/ val loss and accuracy graphs
display(Image.open('runs/detect/train/results.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x1200>

# %% [markdown]
# ## Evaluating the Train/ Loss Graph
#
# These graphs were very impressive to me especially in comparison to the train/ loss graphs on the previous two DETR models. These models achieved close to perfect (and sometimes) perfect recall as well as an AP50 of allmost 1 as well so almost every label was correctly predicted and the placement was very close.
#
# The validation loss seems to follow the training loss for each loss type (class, box and focal) so I believe that the model is not overfitting since there is no divergence towards the end of the model training. Additionally, I don't think there is underfitting since the model performs very well on both the training and validation sets as discussed above. Thus, the model seems to be balanced.

# %%
# Gettings metrics and results for the testing set
model.val(split='test', plots=True)

# Show the validation results
display(Image.open('/content/runs/detect/train2/val_batch0_pred.jpg'))
# Out:
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/AnnotatedDataYoloFormat/test/labels... 3 images, 0 backgrounds, 0 corrupt: 100%|██████████| 3/3 [00:00<00:00, 352.49it/s]
# val: New cache created: /content/AnnotatedDataYoloFormat/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  3.18it/s]
#                    all          3         79      0.978      0.987      0.992      0.902
# Speed: 0.4ms preprocess, 67.5ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to runs/detect/train2
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1344x1344>
